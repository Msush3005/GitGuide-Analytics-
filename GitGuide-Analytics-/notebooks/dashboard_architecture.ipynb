# %% [markdown]
# # Dashboard Architecture & Information Hierarchy
#
# This notebook demonstrates building executive dashboards based on human visual attention:
# 1. **Level 1 (Status)**: Top 5 KPI Summary Cards.
# 2. **Level 2 (Trends)**: Time-series revenue & customer trend charts with target lines.
# 3. **Level 3 (Segments)**: Customer segment revenue breakdown bar charts.
# 4. **Level 4 (Detail)**: Interactive filters and progressive disclosure data exports.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Verify chart output assets
output_files = os.listdir('../output') if os.path.exists('../output') else os.listdir('output')
print("Output Dashboard Chart Assets:")
for f in output_files:
    if f.endswith('.png'):
        print(f"  - {f}")

# %% [markdown]
# ## Level 1: Status KPI Summary

# %%
kpis = pd.DataFrame({
    'Metric': ['Monthly Revenue', 'Active Customers', 'Avg Order Value', 'Churn Rate', 'NPS Score'],
    'Value': ['$5.2M', '2,500', '$145', '4.8%', '72'],
    'Delta': ['+12.5%', '+5.2%', '+3.1%', '-1.2%', '+4 pts'],
    'Status': ['On Track', 'On Track', 'On Track', 'Improving', 'Excellent']
})
print("Level 1 Status KPI Cards:")
print(kpis)

# %% [markdown]
# ## Level 3: Segment Revenue Breakdown

# %%
segments_df = pd.DataFrame({
    'Segment': ['Enterprise', 'Mid-Market', 'SMB', 'Starter'],
    'Revenue_Millions': [2.1, 1.5, 1.0, 0.6],
    'Share_Pct': [40.4, 28.8, 19.2, 11.6]
})
print("Level 3 Segment Revenue Breakdown:")
print(segments_df)
