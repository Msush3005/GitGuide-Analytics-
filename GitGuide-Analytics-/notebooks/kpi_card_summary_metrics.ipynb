# %% [markdown]
# # KPI Card & Summary Metric Design
#
# This notebook demonstrates designing, computing, and formatting executive KPI summary cards:
# 1. **Task 1: Computing 5 Core KPIs** (Total Revenue, Active Users, AOV, Churn Rate, CSAT).
# 2. **Task 2: Adding Trend Indicators & Inverted Status Colors** (Churn Rate decrease is Green).
# 3. **Task 3: Formatting Percentage Change & Human-Readable Numbers**.
# 4. **Task 4: Designing Dashboard Header Layouts** (`kpi_dashboard.py`).
# 5. **Task 5: Documenting Data Lineage & Auto-Updating Architecture** (`kpi_sources.md`).

# %%
import os
import pandas as pd

csv_path = 'output/kpi_summary_report.csv' if os.path.exists('output/kpi_summary_report.csv') else '../output/kpi_summary_report.csv'
df_kpi = pd.read_csv(csv_path)
print("Executive KPI Card Summary Report:")
print(df_kpi[['Metric', 'Display_Val', 'Change_Display', 'Trend_Arrow', 'Status']])
