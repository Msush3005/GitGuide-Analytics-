# %% [markdown]
# # Data Storytelling & Insight Narrative
#
# This notebook demonstrates structuring data analysis into an executive narrative arc:
# 1. **Task 1: The 5-Part Narrative Arc** (Context -> Data -> Finding -> Why -> Action).
# 2. **Task 2: Quantitative Evidence Breakdown** (`supporting_evidence/evidence_breakdown.md`).
# 3. **Task 3: Technical-to-Business Jargon Translation**.
# 4. **Task 4: Three Actionable Recommendations**.
# 5. **Task 5 & 6: Standalone Executive Summary & Peer Clarity Testing**.

# %%
import os

narrative_path = 'analysis_narrative.md' if os.path.exists('analysis_narrative.md') else '../analysis_narrative.md'
with open(narrative_path, 'r', encoding='utf-8') as f:
    print("--- Executive Summary Preview ---")
    print(f.read()[:600] + "\n\n[... Content Continues ...]")
